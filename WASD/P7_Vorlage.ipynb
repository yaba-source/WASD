# %% [markdown]
# # P7 Vorlage: Pandas für Fortgeschrittene (Teil 2)

# %% [markdown]
# In diesem Versuch sollen erneut einige fortgeschrittenene Anwendungen von Pandas geübt werden.
#
# Zunächst wird die NBA-Datenbank eingelesen und dargestellt:

# %%
import pandas as pd
nba = pd.read_csv("nba_all_elo.csv")

# %%
pd.set_option("display.max.columns", None)
nba.tail(20)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126294      63148  201505240CLE   NBA        0     2015  5/24/2015
# 126295      63148  201505240CLE   NBA        1     2015  5/24/2015
# 126296      63149  201505250HOU   NBA        1     2015  5/25/2015
# 126297      63149  201505250HOU   NBA        0     2015  5/25/2015
# 126298      63150  201505260CLE   NBA        0     2015  5/26/2015
# 126299      63150  201505260CLE   NBA        1     2015  5/26/2015
# 126300      63151  201505270GSW   NBA        1     2015  5/27/2015
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126302      63152  201506040GSW   NBA        1     2015   6/4/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# ...

# %% [markdown]
# #  Aufgaben
#
# 1) In wie vielen Spielen erzielte eine der Mannschaften weniger als 50 Punkte? In wie vielen mehr als 150 Punkte?
# 2) Geben Sie die Zeile (= das Spiel) aus, bei dem die höchste je erzielte Punktzahl erreicht wurde.
# 3) Wie viele Spiele haben die Boston Celtics (`team_id` = BOS) im gesamten Zeitraum gespielt?
# 4) Wie viele Punkte erzielten die Golden State Warriors (`team_id`= GSW) im Schnitt (=arithmetisches Mittel) im gesamten Zeitraum und wie viele im Zeitraum seit dem Jahr 2000?
# 5) Wie hat sich die Anzahl der Punkte  pro Spiel über die Jahre geändert? Erstellen Sie eine geeignete Visualisierung.
# 6) Erzeugen Sie die neue Spalte `difference` im DataFrame nba. Diese soll die Differenz zwischen der Spalte `pts`und der Spalte `opp_pts` enthalten. Visualisieren Sie die Häufigkeitsverteilung der Punktedifferenzen der Spiele (ohne Kopien -> Spalte `_iscopy == 0`) mit einem Histogram.

# %% [markdown]
# ## Lösung:

# %% [markdown]
# ### Teilaufgabe 1
#
# In wie vielen Spielen erzielte eine der Mannschaften weniger als 50 Punkte? In wie vielen mehr als 150 Punkte?

# %% [markdown]
# ### Teilaufgabe 2
#
# Geben Sie die Zeile (= das Spiel) aus, bei dem die höchste je erzielte Punktzahl erreicht wurde.

# %% [markdown]
# ### Teilaufgabe 3
#
# Wie viele Spiele haben die Boston Celtics (`team_id` = BOS) im gesamten Zeitraum gespielt?

# %% [markdown]
# ### Teilaufgabe 4
#
# Wie viele Punkte erzielten die Golden State Warriors (`team_id`= GSW) im Schnitt (=arithmetisches Mittel) im gesamten Zeitraum und wie viele im Zeitraum seit dem Jahr 2000?

# %% [markdown]
# ### Teilaufgabe 5
#
# Wie hat sich die Anzahl der Punkte pro Spiel über die Jahre geändert? Erstellen Sie eine geeignete Visualisierung.

# %% [markdown]
# ### Teilaufgabe 6
#
# Erzeugen Sie die neue Spalte `difference` im DataFrame nba. Diese soll die Differenz zwischen der Spalte `pts`und der Spalte `opp_pts` enthalten.
# Visualisieren Sie die Häufigkeitsverteilung der Punktedifferenzen der Spiele (ohne Kopien -> Spalte `_iscopy == 0`) mit einem Histogram.
